# %%
#Setup
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

os.chdir('../data_files') #Set working directory to shorten paths

# %%
#Import Data
f12c_mcsum = pd.read_csv('CRESST/Fig12ckgkeVd_Sum.txt',encoding='utf-16',comment="#",header=None)
#f12c_data = pd.read_csv('CRESST/Fig12ckgkeVd_Data.txt',encoding='utf-16',comment="#",header=None) #why did I trace this in the first place
f12c_NER = pd.read_csv('CRESST/Fig12ckgkeVd_NER.txt',encoding='utf-16',comment="#",header=None)
f12c_AER = pd.read_csv('CRESST/Fig12ckgkeVd_AER.txt',encoding='utf-16',comment="#",header=None)
f12c_IR = pd.read_csv('CRESST/Fig12ckgkeVd_IR.txt',encoding='utf-16',comment="#",header=None)
f12c_IC = pd.read_csv('CRESST/Fig12ckgkeVd_IC.txt',encoding='utf-16',comment="#",header=None)

f3_8bnu = pd.read_csv('EDW/Fig3_8BNeutrinos.txt',encoding='utf-16',comment="#",header=None)
f3_beta = pd.read_csv('EDW/Fig3_Betas.txt',encoding='utf-16',comment="#",header=None)
f3_cosmo = pd.read_csv('EDW/Fig3_cosmogenics.txt',comment="#",header=None)
f3_heat = pd.read_csv('EDW/Fig3_Heat.txt',encoding='utf-16',comment="#",header=None)
f3_lead = pd.read_csv('EDW/Fig3_Lead.txt',encoding='utf-16',comment="#",header=None)
f3_nu = pd.read_csv('EDW/Fig3_Neutrinos.txt',encoding='utf-16',comment="#",header=None)
f3_trit = pd.read_csv('EDW/Fig3_Tritium.txt',encoding='utf-16',comment="#",header=None)
f3_wimp = pd.read_csv('EDW/Fig3_wimps.txt',encoding='utf-16',comment="#",header=None)

f9TL = pd.read_csv('DAMIC/Fig9TL.txt',comment="#",header=None)
f9BL = pd.read_csv('DAMIC/Fig9BL.txt',comment="#",header=None)

f6TR_cevns = pd.read_csv('SNOLAB/Fig6TR_cevns.txt',comment="#",header=None)
f6TR_compton = pd.read_csv('SNOLAB/Fig6TR_compton.txt',comment="#",header=None)
f6TR_surb = pd.read_csv('SNOLAB/Fig6TR_SurfaceBetas.txt',encoding='utf-16',comment="#",header=None)
f6TR_surs = pd.read_csv('SNOLAB/Fig6TR_SurfaceScattering.txt',encoding='utf-16',comment="#",header=None)
f6TR_nu = pd.read_csv('SNOLAB/Fig6TR_neutrons.txt',encoding='utf-16',comment="#",header=None)
f6TR_total = pd.read_csv('SNOLAB/Fig6TR_total.txt',comment="#",header=None)

f6BR_cevns = pd.read_csv('SNOLAB/Fig6BR_cevns.txt',encoding='utf-16',comment="#",header=None)
f6BR_compton = pd.read_csv('SNOLAB/Fig6BR_compton.txt',encoding='utf-16',comment="#",header=None)
f6BR_surb = pd.read_csv('SNOLAB/Fig6BR_SurfaceBetas.txt',encoding='utf-16',comment="#",header=None)
f6BR_surs = pd.read_csv('SNOLAB/Fig6BR_SurfaceScattering.txt',encoding='utf-16',comment="#",header=None)
f6BR_nu = pd.read_csv('SNOLAB/Fig6BR_neutrons.txt',encoding='utf-16',comment="#",header=None)
f6BR_total = pd.read_csv('SNOLAB/Fig6BR_total.txt',encoding='utf-16',comment="#",header=None)
f6BR_Ge = pd.read_csv('SNOLAB/Fig6BR_GeActivation.txt',encoding='utf-16',comment="#",header=None)

f7TR_cevns = pd.read_csv('SNOLAB/Fig7TR_cevns.txt',comment="#",header=None)
f7TR_compton = pd.read_csv('SNOLAB/Fig7TR_compton.txt',encoding='utf-16',comment="#",header=None)
f7TR_surb = pd.read_csv('SNOLAB/Fig7TR_SurfaceBetas.txt',encoding='utf-16',comment="#",header=None)
f7TR_surs = pd.read_csv('SNOLAB/Fig7TR_SurfaceScattering.txt',encoding='utf-16',comment="#",header=None)
f7TR_nu = pd.read_csv('SNOLAB/Fig7TR_neutrons.txt',comment="#",header=None)
f7TR_total = pd.read_csv('SNOLAB/Fig7TR_total.txt',encoding='utf-16',comment="#",header=None)

f7BR_cevns = pd.read_csv('SNOLAB/Fig7BR_cevns.txt',comment="#",header=None)
f7BR_compton = pd.read_csv('SNOLAB/Fig7BR_compton.txt',encoding='utf-16',comment="#",header=None)
f7BR_surb = pd.read_csv('SNOLAB/Fig7BR_SurfaceBetas.txt',encoding='utf-16',comment="#",header=None)
f7BR_surs = pd.read_csv('SNOLAB/Fig7BR_SurfaceScattering.txt',encoding='utf-16',comment="#",header=None)
f7BR_nu = pd.read_csv('SNOLAB/Fig7BR_neutrons.txt',comment="#",header=None)
f7BR_total = pd.read_csv('SNOLAB/Fig7BR_total.txt',comment="#",header=None)
f7BR_Ge = pd.read_csv('SNOLAB/Fig7BR_GeActivation.txt',encoding='utf-16',comment="#",header=None)

f4_Si = pd.read_csv('SNOLAB/Fig4L.txt',comment="#",header=None)
f4_Ge = pd.read_csv('SNOLAB/Fig4R.txt',comment="#",header=None)

#Check data format
print(f3_wimp)
# Out:
#           0         1
# 0    0.1045  0.001360
# 1    0.1055  0.001360
# 2    0.1065  0.001360
# 3    0.1076  0.001360
# 4    0.1087  0.001360
# ..      ...       ...
# 261  3.5880  0.000011
# 262  3.6237  0.000011
# 263  3.6596  0.000011
# 264  3.6959  0.000011
# 265  3.7324  0.000011
#
# [266 rows x 2 columns]

# %% [markdown]
# # CRESST
#
# ![](../data_files/CRESST/Fig12c.png)

# %%
#plt.plot(f12c_data[0],f12c_data[1],label='Data',color='k')
plt.plot(f12c_mcsum[0],f12c_mcsum[1],label='Sum (traced)',color='r')
plt.plot(f12c_IR[0],f12c_IR[1],label='IR')
plt.plot(f12c_AER[0],f12c_AER[1],label='AER',color='g')
plt.plot(f12c_NER[0],f12c_NER[1],label='NER',color='grey')
plt.plot(f12c_IC[0],f12c_IC[1],label='IC')

plt.yscale('log')
plt.ylim(8e-3,7e2); plt.xlim(0,40)
#plt.tick_params(axis='y', which='both', labelleft='off', labelright='on') #duplicates, not moves
plt.ylabel('(kg keV d)$^{-1}$')
plt.legend()
plt.show()

# %% [markdown]
# # EDW III
# ![](../data_files/EDW/Fig3.png)

# %%
#attempt to implement analytically -- from appendix
def tritium(E):
    p0 = 1.406e-8
    p1 = 18.6
    p2 = 511
    return p0*(p1-E)**2*(p2+E)*(E**2+2*p2*E)**(1/2)

def surfbet(E):
    p0 = 1.34
    p1 = -0.058
    p2 = 0.2
    p3 = 40
    p4 = 11.4
    return p0*np.exp(p1*E)+p2*np.exp(-(E-p3)**2/(2*p4**2))

def lead(E):
    p0 = 0.037
    p1 = 0.15
    p2 = 95
    p3 = 5.7
    return p0+p1*np.exp(-(E-p2)**2/(2*p3**2))

def heat(E):
    p0 = 38.2725
    p1 = 0.293
    p2 = 1.4775
    p3 = 0.0812
    return p0*np.exp(-p1*E)+p2*np.exp(-p3*E)

def neutrons(E):
    p0 = 4.827e-4
    p1 = 0.3906
    p2 = 2.986e-4
    p3 = 0.05549
    return p0*np.exp(-p1*E)+p2*np.exp(-p3*E)

# %%
plt.plot(f3_wimp[0],f3_wimp[1],label='Wimps',color='b')
plt.axhline(1e-1,label='Compton',color='skyblue')
plt.vlines(f3_cosmo[0],ymin=1e-6,ymax=f3_cosmo[1],label='Cosmogenics',color='teal')
plt.plot(f3_heat[0],heat(f3_heat[0]),label='Heat',color='r') #probably won't use -- specific to edw
plt.plot(f3_beta[0],surfbet(f3_beta[0]),label='Betas',color='purple')
plt.plot(f3_lead[0],lead(f3_lead[0]),label='Lead')#,color='yellow') #I don't like that choice it's hard to see
plt.plot(f3_8bnu[0],f3_8bnu[1],label='$^8$B Neutrinos',color='grey')
plt.plot(f3_nu[0],neutrons(f3_nu[0]),label='Neutrinos',color='k')
plt.plot(f3_trit[0],tritium(f3_trit[0]),label='Tritium',color='orange')

plt.ylim(1e-5,1e2); plt.xlim(1e-1,1e2)
plt.yscale('log'); plt.xscale('log')
plt.legend()
plt.show()

# %% [markdown]
# # DAMIC

# %% [markdown]
# ## Top Left
# ![](../data_files/DAMIC/Fig9TL.png)

# %%
plt.scatter(f9TL[0],f9TL[1])
plt.yscale('log')
plt.xlim(6,20); plt.ylim(2e-2,2e2)
plt.show()

# %% [markdown]
# ## Top Right
# ![](../data_files/DAMIC/Fig9BL.png)

# %%
plt.scatter(f9BL[0],f9BL[1])
plt.yscale('log')
plt.xlim(6,20); plt.ylim(3e-4,2e1)
plt.show()

# %% [markdown]
# # SNOLAB
# Thick black lines represent the total background rates. Electron recoils from
# Compton gamma-rays, 3H, and 32Si are grouped together (red). The Ge activation lines (grey) are shown convolved with a
# 10 eV r.m.s. resolution. The remaining components are surface betas (green), surface 206Pb recoils (orange), neutrons (blue),
# and CEνNS (cyan).

# %% [markdown]
# ## Figure 6, Top Right
# ![](../data_files/SNOLAB/Fig6TR.png)

# %%
plt.plot(f6TR_surb[0],f6TR_surb[1],label='Surface Betas',color='g')
plt.plot(f6TR_surs[0],f6TR_surs[1],label='Surface Recoils',color='orange')
plt.plot(f6TR_nu[0],f6TR_nu[1],label='Neutrons',color='b')
plt.plot(f6TR_compton[0],f6TR_compton[1],label='Compton',color='r')
plt.plot(f6TR_cevns[0],f6TR_cevns[1],label='CEvNS',color='teal')
plt.plot(f6TR_total[0],f6TR_total[1],label='Total (traced)',color='k')

plt.yscale('log'),plt.xscale('log')
plt.ylim(1e-4,1e4); plt.xlim(4e-2,3e1)
plt.legend()
plt.show()

# %% [markdown]
# ## Figure 6, Bottom Right
# ![](../data_files/SNOLAB/Fig6BR.png)

# %%
plt.plot(f6BR_nu[0],f6BR_nu[1],color='b',label='Neutrons')
plt.plot(f6BR_compton[0],f6BR_compton[1],color='r',label='Compton')
plt.plot(f6BR_surb[0],f6BR_surb[1],color='g',label='Surface Betas')
plt.plot(f6BR_surs[0],f6BR_surs[1],color='orange',label='Surface Recoils')
plt.plot(f6BR_cevns[0],f6BR_cevns[1],color='teal',label='CEvNS')
#These two are of poor quality, but they're not the region we're most interested in and were the hardest to trace. So, maybe ok?
plt.scatter(f6BR_Ge[0],f6BR_Ge[1],color='grey',linewidth=0.5,label='Ge Activation')
plt.scatter(f6BR_total[0],f6BR_total[1],color='k',label='Total (traced)')

plt.legend(loc='upper left') #makes it hard to see certain points
plt.yscale('log'); plt.xscale('log')
plt.ylim(1e-4,1e6); plt.xlim(4e-2,3e1)
plt.show()

# %% [markdown]
# ## Figure 7: Top Right
# ![](../data_files/SNOLAB/Fig7TR.png)

# %%
plt.plot(f7TR_compton[0],f7TR_compton[1],color='r',label='Compton')
plt.scatter(f7TR_surb[0],f7TR_surb[1],color='g',label='Surface Betas',s=0.5)
plt.plot(f7TR_surs[0],f7TR_surs[1],color='orange',label='Surface Recoils')
plt.plot(f7TR_nu[0],f7TR_nu[1],color='b',label='Neutrons')
plt.plot(f7TR_cevns[0],f7TR_cevns[1],color='teal',label='CEvNS')
plt.plot(f7TR_total[0],f7TR_total[1],color='k',label='Total (traced)')

plt.yscale('log'); plt.xscale('log')
plt.ylim(1e-4,1e4); plt.xlim(4e-2,2e2)
plt.legend()
plt.show()

# %% [markdown]
# ## Figure 7: Bottom Right
#
# ![](../data_files/SNOLAB/Fig7BR.png)

# %%
plt.plot(f7BR_surb[0],f7BR_surb[1],color='g',label='Surface Betas')
plt.plot(f7BR_compton[0],f7BR_compton[1],color='r',label='Compton')
plt.plot(f7BR_surs[0],f7BR_surs[1],color='orange',label='Surface Scattering')
plt.plot(f7BR_nu[0],f7BR_nu[1],color='b',label='Neutrons')
plt.plot(f7BR_cevns[0],f7BR_cevns[1],color='teal',label='CEvNS')
plt.scatter(f7BR_Ge[0],f7BR_Ge[1],color='grey',s=0.5,label='Ge Activation') #using scatter for ones that go below the plotted area
plt.scatter(f7BR_total[0],f7BR_total[1],color='k',s=3,label='Total (traced)')  #to keep from making lines between distant points

plt.legend()
plt.xscale('log'); plt.yscale('log')
plt.ylim(1e-4,1e5); plt.xlim(4e-2,2e2)
plt.show()

# %% [markdown]
# ## Figure 4: Left
#
# Raw background spectra of single scatter interactions in a Si (left) and Ge (right) detector obtained from the Monte
# Carlo simulation. The spectra are broken out by components and shown as a function of recoil energy (ER or NR depending
# on the interaction). 3H (pink) and 32Si (purple) are the largest individual contributors to the backgrounds in the Ge and Si
# detectors, respectively. The Ge activation lines (black) are shown convolved with a 10 eV r.m.s. resolution (σP h for the Ge
# HV detectors) to allow them to be clearly displayed in this figure. The remaining components are Compton scatters from
# gamma-rays (red), surface betas (green), surface 206Pb recoils (orange), neutrons (blue) and coherent elastic neutrino-nucleus
# scattering (cyan). Note that the neutron spectrum (blue) has some spurious structure from the limited simulation statistics in
# the cavern component of the neutron background (cf. Table V).
#
# ![](../data_files/SNOLAB/Fig4L.png)

# %%
plt.plot(f4_Si[0],f4_Si[1],color='magenta')

plt.xscale('log'); plt.yscale('log')
plt.ylim(1e-4,1e4); plt.xlim(4e-2,1e2)
plt.show()

# %% [markdown]
# ## Figure 4: Right
# ![](../data_files/SNOLAB/Fig4R.png)

# %%
plt.plot(f4_Ge[0],f4_Ge[1],color='magenta')

plt.xscale('log'); plt.yscale('log')
plt.ylim(1e-4,1e4); plt.xlim(4e-2,1e2)
plt.show()
