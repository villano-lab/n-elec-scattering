# %%
#we may need some code in the ../python directory and/or matplotlib styles
import sys
sys.path.append('../python/')

#matplotlib for plotting
import matplotlib as mpl
from matplotlib import pyplot as plt
plt.style.use('../mplstyles/stylelib/standard.mplstyle')

import numpy as np

# %%
#https://pyteomics.readthedocs.io/en/latest/mass.html
from pyteomics import mass

mass.isotopic_composition_abundance(formula='Ne[20]')
# Out:
# 0.9048

# %%
for m in mass.isotopologues('CaWO3'):
  print(mass.isotopic_composition_abundance(m))
  print(m)
# Out:
# 0.0011548321919968233
# Composition({'Ca[40]': 1, 'W[180]': 1, 'O[16]': 3})
# 7.119518410518024e-06
# Composition({'Ca[40]': 1, 'W[180]': 1, 'O[16]': 2, 'O[18]': 1})
# 1.4630565014547299e-08
# Composition({'Ca[40]': 1, 'W[180]': 1, 'O[16]': 1, 'O[18]': 2})
# 1.00219059915e-11
# Composition({'Ca[40]': 1, 'W[180]': 1, 'O[18]': 3})
# 0.2550254423992986
# Composition({'Ca[40]': 1, 'W[182]': 1, 'O[16]': 3})
# 0.0015722269823227305
# Composition({'Ca[40]': 1, 'W[182]': 1, 'O[16]': 2, 'O[18]': 1})
# 3.2309164407125294e-06
# Composition({'Ca[40]': 1, 'W[182]': 1, 'O[16]': 1, 'O[18]': 2})
# 2.2131709064562506e-09
# Composition({'Ca[40]': 1, 'W[182]': 1, 'O[18]': 3})
# 0.13771373889562122
# Composition({'Ca[40]': 1, 'W[183]': 1, 'O[16]': 3})
# 0.0008490025704542744
# Composition({'Ca[40]': 1, 'W[183]': 1, 'O[16]': 2, 'O[18]': 1})
# 1.744694877984766e-06
# Composition({'Ca[40]': 1, 'W[183]': 1, 'O[16]': 1, 'O[18]': 2})
# 1.1951122894863753e-09
# ...

# %%
for m in mass.isotopologues('Si'):
  print(mass.isotopic_composition_abundance(m))
  print(m)
# Out:
# 0.92223
# Composition({'Si[28]': 1})
# 0.04685
# Composition({'Si[29]': 1})
# 0.03092
# Composition({'Si[30]': 1})

# %%
for m in mass.isotopologues('Ge'):
  print(mass.isotopic_composition_abundance(m))
  print(m)
# Out:
# 0.2038
# Composition({'Ge[70]': 1})
# 0.2731
# Composition({'Ge[72]': 1})
# 0.0776
# Composition({'Ge[73]': 1})
# 0.3672
# Composition({'Ge[74]': 1})
# 0.0783
# Composition({'Ge[76]': 1})

# %%
num=0
isotope_struct={}
isotope_abund={}
for m in mass.isotopologues('CaWO3'):
  #print(mass.isotopic_composition_abundance(m))
  #print(m)
  isotope_struct[num]=m
  isotope_abund[num]=mass.isotopic_composition_abundance(m)
  num=num+1
  
print(isotope_abund)
# Out:
# {0: 0.0011548321919968233, 1: 7.119518410518024e-06, 2: 1.4630565014547299e-08, 3: 1.00219059915e-11, 4: 0.2550254423992986, 5: 0.0015722269823227305, 6: 3.2309164407125294e-06, 7: 2.2131709064562506e-09, 8: 0.13771373889562122, 9: 0.0008490025704542744, 10: 1.744694877984766e-06, 11: 1.1951122894863753e-09, 12: 0.29486715302318894, 13: 0.001817850367485602, 14: 3.7356709337144104e-06, 15: 2.558926663163e-09, 16: 0.2735989934872474, 17: 0.001686732570091895, 18: 3.466224694696499e-06, 19: 2.374356561152875e-09, 20: 7.707537865525884e-06, 21: 4.7516823754708124e-08, 22: 9.76467703491e-11, 23: 6.68878305e-14, 24: 0.0017020812786369664, 25: 1.0493298579164715e-05, 26: 2.1563661785426257e-08, 27: 1.4771062568750002e-11, 28: 0.0009191238904639619, 29: 5.666381232748947e-06, 30: 1.1644377364130179e-08, 31: 7.976373787125002e-12, 32: 0.0019679913349976096, 33: 1.2132628998702148e-05, 34: 2.4932475362470204e-08, 35: 1.7078692721000005e-11, 36: 0.0018260441793075076, 37: 1.1257527494552937e-0
# ...

# %%
sorted_isotopes = sorted(isotope_abund.items(),key=lambda x:x[1],reverse=True)

print(sorted_isotopes)
for i in sorted_isotopes:
    print(isotope_struct[i[0]])
# Out:
# [(12, 0.29486715302318894), (16, 0.2735989934872474), (4, 0.2550254423992986), (8, 0.13771373889562122), (72, 0.006345023067704812), (76, 0.005887369641476756), (64, 0.005487699454770807), (68, 0.0029633577055762357), (32, 0.0019679913349976096), (36, 0.0018260441793075076), (13, 0.001817850367485602), (24, 0.0017020812786369664), (17, 0.001686732570091895), (5, 0.0015722269823227305), (0, 0.0011548321919968233), (28, 0.0009191238904639619), (9, 0.0008490025704542744), (92, 0.000568801205014765), (96, 0.0005277747473423554), (84, 0.0004919462119089841), (52, 0.0004106318859732261), (56, 0.00038101385503325127), (44, 0.00035514833480060354), (88, 0.00026565095443085144), (48, 0.0001917801007923259), (73, 3.911694604527461e-05), (77, 3.629552141211349e-05), (65, 3.383156234333477e-05), (60, 2.4849959795188556e-05), (69, 1.8269043665400774e-05), (33, 1.2132628998702148e-05), (37, 1.1257527494552937e-05), (25, 1.0493298579164715e-05), (20, 7.707537865525884e-06), (1, 7.119518410518024e-0
# ...

# %%
from periodictable import hydrogen
print("H mass %s %s"%(hydrogen.mass, hydrogen.mass_units))
# Out:
# H mass 1.008 u

# %%
import periodictable
for el in periodictable.elements: 
  print("%s %s %s"%(el.symbol,el.name,el.number))
# Out:
# H hydrogen 1
# He helium 2
# Li lithium 3
# Be beryllium 4
# B boron 5
# C carbon 6
# N nitrogen 7
# O oxygen 8
# F fluorine 9
# Ne neon 10
# Na sodium 11
# Mg magnesium 12
# Al aluminum 13
# Si silicon 14
# P phosphorus 15
# S sulfur 16
# Cl chlorine 17
# Ar argon 18
# K potassium 19
# Ca calcium 20
# Sc scandium 21
# Ti titanium 22
# V vanadium 23
# Cr chromium 24
# Mn manganese 25
# Fe iron 26
# Co cobalt 27
# Ni nickel 28
# Cu copper 29
# Zn zinc 30
# Ga gallium 31
# Ge germanium 32
# As arsenic 33
# Se selenium 34
# Br bromine 35
# Kr krypton 36
# Rb rubidium 37
# Sr strontium 38
# Y yttrium 39
# Zr zirconium 40
# Nb niobium 41
# Mo molybdenum 42
# Tc technetium 43
# Ru ruthenium 44
# Rh rhodium 45
# Pd palladium 46
# Ag silver 47
# Cd cadmium 48
# In indium 49
# Sn tin 50
# Sb antimony 51
# Te tellurium 52
# I iodine 53
# Xe xenon 54
# Cs cesium 55
# Ba barium 56
# La lanthanum 57
# Ce cerium 58
# Pr praseodymium 59
# Nd neodymium 60
# Pm promethium 61
# Sm samarium 62
# ...

# %%
print(periodictable.elements)

# %%
print(periodictable.elements.symbol('Fe').number)
print(periodictable.elements[14].symbol)
# Out:
# 26
# Si

# %%
import ENDF6el as el
import flux_recoil_spec as frs
import importlib
import time

# %%
importlib.reload(frs)
importlib.reload(el)
#get Er vector
Er= np.geomspace(100/1e7, 1.0, 100)
print(np.shape(Er))
E,F,ff,ffspec = frs.SNOLAB_flux(Enmin=1e-4)
start = time.time()
drde,dsig=frs.dRdErfast(Er,E,F,N=1)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# (100,)
# fast flux: 4000.0000000000005 n/m^2/day
# 175
# shape of etot: (6000,)
# 6000 6000
# LinregressResult(slope=-0.341989060170171, intercept=-12.883178144228603, rvalue=-0.9953352356165475, pvalue=2.847357267291413e-06, stderr=0.014824519476612728, intercept_stderr=0.06273875262265612)
# 0.009995281867072022 0.01
# ../data_files/xn_data/si28_el.txt ../data_files/xn_data/n-014_Si_028.endf
# Evaluation Time: 333.84821 sec.

# %%
start = time.time()
drde_29Si,dsig_29Si=frs.dRdErfast(Er,E,F,N=1,Z=14,A=29)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# ../data_files/xn_data/si29_el.txt ../data_files/xn_data/n-014_Si_029.endf
# Evaluation Time: 300.24108 sec.

# %%
start = time.time()
drde_30Si,dsig_30Si=frs.dRdErfast(Er,E,F,N=1,Z=14,A=30)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# ../data_files/xn_data/si30_el.txt ../data_files/xn_data/n-014_Si_030.endf
# Evaluation Time: 300.44668 sec.

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0),sharex=True)
ax1 = axes


print(mass.isotopic_composition_abundance({'Si[28]':1}))
p28=mass.isotopic_composition_abundance({'Si[28]':1})
p29=mass.isotopic_composition_abundance({'Si[29]':1})
p30=mass.isotopic_composition_abundance({'Si[30]':1})
#ax1.plot(Er, dRlow,label='low res')
ax1.plot(Er*1000, p28*drde,label="28-Si")
ax1.plot(Er*1000, p29*drde_29Si,label="29-Si")
ax1.plot(Er*1000, p30*drde_30Si,label="30-Si")
ax1.plot(Er*1000, p28*drde+p29*drde_29Si+p30*drde_30Si,color='k',label="total")



ymin = 1e-5
ymax = 1e1

blue = '#118DFA'
#ax1.fill_between(xcq,np.zeros(np.shape(xcq)),thist,step='mid',facecolor='b',alpha=0.4, \
#                 label='')

plt.loglog()
plt.grid()
#ax1.set_yscale('linear')
#ax1.set_yscale('log')
ax1.set_xlim(1e-5*1000, 1*1000) 
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'recoil energy [keV]')
ax1.set_ylabel('rate [events kg$^{-1}$ day$^{-1}$ keV$^{-1}$]')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.savefig('figures/si-nn-spec.png')
plt.show()
# Out:
# 0.92223

# %%
start = time.time()
drde_70Ge,dsig_70Ge=frs.dRdErfast(Er,E,F,N=1,Z=32,A=70)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# ../data_files/xn_data/ge70_el.txt ../data_files/xn_data/n-032_Ge_070.endf
# Evaluation Time: 182.75775 sec.

# %%
start = time.time()
drde_72Ge,dsig_72Ge=frs.dRdErfast(Er,E,F,N=1,Z=32,A=72)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# ../data_files/xn_data/ge72_el.txt ../data_files/xn_data/n-032_Ge_072.endf
# Evaluation Time: 150.53172 sec.

# %%
start = time.time()
drde_73Ge,dsig_73Ge=frs.dRdErfast(Er,E,F,N=1,Z=32,A=73)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# ../data_files/xn_data/ge73_el.txt ../data_files/xn_data/n-032_Ge_073.endf
# Evaluation Time: 304.61107 sec.

# %%
start = time.time()
drde_74Ge,dsig_74Ge=frs.dRdErfast(Er,E,F,N=1,Z=32,A=74)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# ../data_files/xn_data/ge74_el.txt ../data_files/xn_data/n-032_Ge_074.endf
# Evaluation Time: 115.95150 sec.

# %%
start = time.time()
drde_76Ge,dsig_76Ge=frs.dRdErfast(Er,E,F,N=1,Z=32,A=76)
end = time.time()
print('Evaluation Time: {:1.5f} sec.'.format(end-start))
# Out:
# ../data_files/xn_data/ge76_el.txt ../data_files/xn_data/n-032_Ge_076.endf
# Evaluation Time: 137.99203 sec.

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0),sharex=True)
ax1 = axes


print(mass.isotopic_composition_abundance({'Ge[76]':1}))
p70=mass.isotopic_composition_abundance({'Ge[70]':1})
p72=mass.isotopic_composition_abundance({'Ge[72]':1})
p73=mass.isotopic_composition_abundance({'Ge[73]':1})
p74=mass.isotopic_composition_abundance({'Ge[74]':1})
p76=mass.isotopic_composition_abundance({'Ge[76]':1})

#ax1.plot(Er, dRlow,label='low res')
ax1.plot(Er*1000, p70*drde_70Ge,label="70-Ge")
ax1.plot(Er*1000, p72*drde_72Ge,label="72-Ge")
ax1.plot(Er*1000, p73*drde_73Ge,label="73-Ge")
ax1.plot(Er*1000, p74*drde_73Ge,label="74-Ge")
ax1.plot(Er*1000, p76*drde_76Ge,label="76-Ge")
ax1.plot(Er*1000, p70*drde_70Ge + p72*drde_72Ge + p73*drde_73Ge + p74*drde_74Ge + p76*drde_76Ge,color='k',label="total")




ymin = 1e-5
ymax = 1e1

blue = '#118DFA'
#ax1.fill_between(xcq,np.zeros(np.shape(xcq)),thist,step='mid',facecolor='b',alpha=0.4, \
#                 label='')

plt.loglog()
plt.grid()
#ax1.set_yscale('linear')
#ax1.set_yscale('log')
ax1.set_xlim(1e-5*1000, 1*1000) 
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'recoil energy [keV]')
ax1.set_ylabel('rate [events kg$^{-1}$ day$^{-1}$ keV$^{-1}$]')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.savefig('figures/ge-nn-spec.png')
plt.show()
# Out:
# 0.0783

# %%
Er_ne= np.geomspace(0.1e-4, 100e-3, 1000)
drde_ne,dsig_ne=frs.dRdErNE(Er_ne,E,F,N=1,Z=14,A=28)
# Out:
# 14

# %%
import atomic_structure as ats
importlib.reload(ats)

shell_energies = np.array([1.12, 99.2, 150, 1839])/1000
electron_number = np.array([4, 6, 2, 2])

drde_mod = ats.mod_and_plot(Er_ne, drde_ne, shell_energies, electron_number, plot=False)

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0),sharex=True)
ax1 = axes



ax1.plot(Er_ne*1000, drde_ne,label="neutron-electron (unmodified)",linestyle='--',color='r')
ax1.plot(Er_ne*1000, drde_mod,label="neutron-electron",linestyle='-',color='b')
ax1.plot(Er*1000, p28*drde+p29*drde_29Si+p30*drde_30Si,color='k',label="neutron-nucleus")



ymin = 1e-3
ymax = 1e4

blue = '#118DFA'
#ax1.fill_between(xcq,np.zeros(np.shape(xcq)),thist,step='mid',facecolor='b',alpha=0.4, \
#                 label='')

plt.loglog()
plt.grid()
#ax1.set_yscale('linear')
#ax1.set_yscale('log')
ax1.set_xlim(1e-5*1000, 1*100) 
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'recoil energy [keV]')
ax1.set_ylabel('rate [events kg$^{-1}$ day$^{-1}$ keV$^{-1}$]')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.savefig('figures/si-ne-nn-compare.png')
plt.show()

# %%
drde_si_tot = p28*drde+p29*drde_29Si+p30*drde_30Si
drde_ge_tot = p70*drde_70Ge+p72*drde_72Ge+p73*drde_73Ge+p74*drde_74Ge+p76*drde_76Ge

# %%
importlib.reload(frs)
Er_ne_ge= np.geomspace(0.1e-5, 100e-3, 2000)
drde_ne_ge,dsig_ne_ge=frs.dRdErNE(Er_ne_ge,E,F,N=1,Z=32,A=70)
# Out:
# 32

# %%
#K 1s L1 2s L2 2p1/2 L3 2p3/2 M1 3s M2 3p1/2 M3 3p3/2 M4 3d3/2 M5 3d5/2 N1 4s N2 4p1/2 N3 4p3/2
#32 Ge 11103 1414.6*b 1248.1*b 1217.0*b 180.1* 124.9* 120.8* 29.8 29.2


shell_energies_Ge = np.array([29.2, 29.8, 120.8, 124.8, 180.1, 1217, 1248.1, 1414.6, 11103])/1000
electron_number_Ge = np.array([2, 2, 6, 2, 6, 10, 4, 2, 2])

drde_mod_ge = ats.mod_and_plot(Er_ne_ge, drde_ne_ge, shell_energies_Ge, electron_number_Ge, plot=False)

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0),sharex=True)
ax1 = axes



ax1.plot(Er_ne*1000, drde_ne,label="neutron-electron (unmodified)",linestyle='--',color='r')
ax1.plot(Er_ne*1000, drde_mod,label="neutron-electron",linestyle='-',color='b')
ax1.plot(Er*1000, drde_si_tot,color='k',label="neutron-nucleus")

ax1.plot(Er_ne_ge*1000, drde_ne_ge,label='',linestyle='--',color='m')
ax1.plot(Er_ne_ge*1000, drde_mod_ge,label="",linestyle='-',color='cyan')
ax1.plot(Er*1000, drde_ge_tot,color='gray',label="neutron-nucleus (Ge)")



ymin = 1e-3
ymax = 1e4

blue = '#118DFA'
#ax1.fill_between(xcq,np.zeros(np.shape(xcq)),thist,step='mid',facecolor='b',alpha=0.4, \
#                 label='')

plt.loglog()
plt.grid()
#ax1.set_yscale('linear')
#ax1.set_yscale('log')
ax1.set_xlim(1e-5*1000, 1*100) 
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'recoil energy [keV]')
ax1.set_ylabel('rate [events kg$^{-1}$ day$^{-1}$ keV$^{-1}$]')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=3,prop={'size':18})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.savefig('figures/ge-ne-nn-compare.png')
plt.show()
