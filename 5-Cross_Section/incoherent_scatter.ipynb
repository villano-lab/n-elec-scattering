# %% [markdown]
# # Comparing Incoherent Scattering Functions
# Incoherent scattering functions and structure effects in general are related to the cross section for neutron magnetic scattering. For an accurate cross section calculation, we need to determine if local electron behavior, random scattering etc. play a significant role in Neutron magnetic scattering probability. These are accounted for in incoherent scattering functions. Here we plot comparisons of traces of scattering functions from various sources.

# %%
import matplotlib.pyplot as plt

# Manually define the x and y values from the provided data points
x_values = [
    0.4953, 0.2992, 0.3206, 0.3384, 0.3562, 0.367, 0.3812, 0.4062,
    0.3919, 0.4276, 0.4186, 0.4418, 0.4596, 0.5525, 0.5632, 0.5703,
    0.5952, 0.6059, 0.6256, 0.1532, 0.0678, 0.0909, 1.2483, 1.3768,
    1.7981, 2.2551
]

y_values = [
    0.6117, 0.4282, 0.4478, 0.4815, 0.4781, 0.4729, 0.4695, 0.4767,
    0.4925, 0.5122, 0.5263, 0.5265, 0.5636, 0.5644, 0.5838, 0.6158,
    0.6195, 0.6514, 0.6444, 0.1885, 0.0447, 0.0661, 0.8965, 0.9258,
    0.9713, 0.9959
]

# Plot the data
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, marker='o', linestyle='None', color='b')
plt.title('Atomic Al - Experimental Data')
plt.xlabel(r"$x,\ \frac{\sin(\theta/2)}{\lambda} (\AA)$")
plt.ylabel(r"$\frac{S(x, Z)}{Z}$", rotation=0, labelpad=30, loc='center')
plt.grid(True)
plt.show()

# %% [markdown]
# (Fig. 2 from Ribberfors & Berggren, Phys. Rev. A, 1982)

# %% [markdown]
# ### Overlaying Scattering Functions for Al, Be, and C
# Seeing how different structure effects are for different elements in general.

# %%
import matplotlib.pyplot as plt
import pandas as pd
#from google.colab import drive
from pathlib import Path

notebook_dir = Path().resolve()
# Gets the current working directory - get trace data 
file_path = notebook_dir / "Datathief" / "fig42trace.txt"
file_path1 =  notebook_dir / "Datathief" / "fig43trace.txt"
file_path2 =  notebook_dir / "Datathief" / "fig2trace.txt"

# Figure 42 and 43 from Hubbell 1975
# Figure 2 from R. Ribberfors, and K. F. Berggren 
# Phys. Rev. A Vol. 26 Num. 6

#For google Colab Notebooks otherwise ignore
# Mount Google Drive (correct path)
# drive.mount('/content/drive')

# file_path = '/content/drive/MyDrive/Colab Notebooks/villano rsrch/fig42trace.txt'
# file_path1 = '/content/drive/MyDrive/Colab Notebooks/villano rsrch/fig43trace.txt'
# file_path2 = '/content/drive/MyDrive/Colab Notebooks/villano rsrch/fig2trace.txt'

data = []
data1 = []
data2 = []

with open(file_path, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data.append([float(values[0]), float(values[1])])

with open(file_path1, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data1.append([float(values[0]), float(values[1])])

with open(file_path2, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data2.append([float(values[0]), float(values[1])])

df = pd.DataFrame(data, columns=['X', 'Y'])
df1 = pd.DataFrame(data1, columns=['X','Y'])
df2 = pd.DataFrame(data2, columns=['X','Y'])

plt.plot(df['X'], df['Y'], marker='o', linestyle='-', color='b', alpha=0.3, markersize=0.4, markeredgewidth=2, label= r'Beryllium, Cromer-Mann Configurations$^{1}$')
#Cromer-Mann Calculations for Be
plt.plot(df1['X'], df1['Y'], marker='x', linestyle='-', color='r', alpha=0.3, markersize=0.4, markeredgewidth=2, label =r'Carbon, Cromer-Mann Configuration$^{1}$')
#Cromer Configuration for C
plt.plot(df2['X'], df2['Y'], marker='x', linestyle='-', color='g', alpha=0.3, markersize=0.4, markeredgewidth=2, label = r'Aluminum, Hartree-Fock$^{2}$')
#Fig 2 nonrelativistic Hartree-Fock Calculations for S(x,Z) atomic Al (Ribberfors)

#Figures 42 and 43 have Hartree Fock configurations add in later

plt.title('Incoherent Scattering Functions')
# plt.ylabel('S(x,Z)/Z')
# plt.xlabel('x, sin(theta/2)/lambda')
plt.ylabel(r"$\frac{S(x, Z)}{Z}$", rotation=0, labelpad=30, loc='center')
plt.xlabel(r"$x,\ \frac{\sin(\theta/2)}{\lambda} (\AA)$")
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# 1. (Fig. 42 & 43 from Hubbell, J. Phys. Chem. Ref., 1975)
# 2. (Fig. 2 from Ribberfors & Berggren, Phys. Rev. A, 1982)

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt


notebook_dir = Path().resolve()
Hubbell_Si = notebook_dir / "Datathief" / "hubbell" / "Hubbell_Si.csv"
Hubbell_Ge =  notebook_dir / "Datathief" / "hubbell" / "Hubbell_Ge.csv"

df_Si1=pd.read_csv(Hubbell_Si)
df_Ge1=pd.read_csv(Hubbell_Ge)


print(df_Si1)
print(df_Ge1)
ax = plt.gca()
ax.set_xlim(0, 10)
plt.plot(df_Si1['x'], df_Si1['S(x,Z)']/14, label = "Si")
plt.plot(df_Ge1['x'], df_Ge1['S(X,Z)']/32, label = "Ge")
plt.ylabel(r"$\frac{S(x, Z)}{Z}$", rotation=0, labelpad=30, loc='center')
plt.xlabel(r"$x,\ \frac{\sin(\theta/2)}{\lambda} (\AA^{-1})$")
plt.legend(loc='lower right')
plt.grid(True)
# Out:
#                x   S(x,Z)
# 0   0.000000e+00   0.0000
# 1   5.000000e-03   0.0090
# 2   1.000000e-02   0.0350
# 3   1.500000e-02   0.0790
# 4   2.000000e-02   0.1391
# 5   2.500000e-02   0.2148
# 6   3.000000e-02   0.3049
# 7   4.000000e-02   0.5229
# 8   5.000000e-02   0.7820
# 9   7.000000e-02   1.3724
# 10  9.000000e-02   1.9915
# 11  1.000000e-01   2.2930
# 12  1.250000e-01   2.9884
# 13  1.500000e-01   3.5870
# 14  1.750000e-01   4.0921
# 15  2.000000e-01   4.5200
# 16  2.500000e-01   5.2175
# 17  3.000000e-01   5.8080
# 18  4.000000e-01   6.9030
# 19  5.000000e-01   7.9370
# 20  6.000000e-01   8.8670
# 21  7.000000e-01   9.6670
# 22  8.000000e-01  10.3300
# 23  9.000000e-01  10.8640
# 24  1.000000e+00  11.2860
# 25  1.250000e+00  11.9900
# 26  1.500000e+00  12.4080
# 27  2.000000e+00  12.8370
# 28  2.500000e+00  13.3020
# 29  3.000000e+00  13.5580
# 30  3.500000e+00  13.7260
# 31  4.000000e+00  13.8320
# 32  5.000000e+00  13.9370
# 33  6.000000e+00  13.9750
# 34  7.000000e+00  13.9950
# 35  8.000000e+00  13.9950
# 36  1.000000e+01  13.9990
# 37  1.500000e+01  14.0000
# 38  2.000000e+01  14.0000
# 39  5.000000e+01  14.0000
# 40  8.000000e+01  14.0000
# 41  1.000000e+02  14.0000
# 42  1.000000e+03  14.0000
# 43  1.000000e+06  14.0000
# 44  1.000000e+09  14.0000
#                x   S(X,Z)
# 0   0.000000e+00   0.0000
# 1   5.000000e-03   0.0110
# 2   1.000000e-02   0.0420
# 3   1.500000e-02   0.0949
# 4   2.000000e-02   0.1671
# 5   2.500000e-02   0.2582
# 6   3.000000e-02   0.3667
# 7   4.000000e-02   0.6300
# 8   5.000000e-02   0.9440
# 9   7.000000e-02   1.6691
# 10  9.000000e-02   2.4486
# 11  1.000000e-01   2.8390
# 12  1.250000e-01   3.7810
# 13  1.500000e-01   4.6590
# 14  1.750000e-01   5.4723
# 15  2.000000e-01   6.2290
# 16  2.500000e-01   7.6188
# 17  3.000000e-01   8.9120
# 18  4.000000e-01  11.3380
# 19  5.000000e-01  13.5360
# 20  6.000000e-01  15.4860
# 21  7.000000e-01  17.2150
# 22  8.000000e-01  18.7410
# 23  9.000000e-01  20.0740
# 24  1.000000e+00  21.2240
# 25  1.250000e+00  23.4300
# 26  1.500000e+00  24.9830
# 27  2.000000e+00  27.1090
# 28  2.500000e+00  28.4920
# 29  3.000000e+00  29.3770
# 30  3.500000e+00  29.9470
# 31  4.000000e+00  30.3400
# 32  5.000000e+00  30.8720
# 33  6.000000e+00  31.2360
# 34  7.000000e+00  31.4920
# 35  8.000000e+00  31.6680
# 36  1.000000e+01  31.8600
# 37  1.500000e+01  31.9820
# 38  2.000000e+01  31.9970
# 39  5.000000e+01  32.0000
# 40  8.000000e+01  32.0000
# 41  1.000000e+02  32.0000
# 42  1.000000e+03  32.0000
# 43  1.000000e+06  32.0000
# 44  1.000000e+09  32.0000

# %% [markdown]
# ### Incoherent Scattering functions for Ge and Si from Freeman, 1959
# Many detectors for rare event searches are made of germanium or silicon.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

notebook_dir = Path().resolve() 
file_path_Ge = notebook_dir / "Datathief" / "Freeman_Ge_trace.txt"
file_path_Ge_WH = notebook_dir / "Datathief" / "Freeman_Ge_WH_trace.txt"



data_Ge = []
data_Ge_WH = []

with open(file_path_Ge, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data_Ge.append([float(values[0]), float(values[1])])

with open(file_path_Ge_WH, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data_Ge_WH.append([float(values[0]), float(values[1])])

df_Ge= pd.DataFrame(data_Ge, columns=['X','Y'])
df_Ge_WH = pd.DataFrame(data_Ge_WH, columns=['X','Y'])

plt.plot(df_Ge['X'], df_Ge['Y']/32, marker='x', linestyle='-', color='r', alpha=0.3, markersize=0.4, markeredgewidth=2, label ='Ge')
plt.plot(df_Ge_WH['X'], df_Ge_WH['Y']/32, marker='x', linestyle='-', color='g', alpha=0.3, markersize=0.4, markeredgewidth=2, label = 'Ge Waller Hartree')

plt.title('Germanium*')
plt.ylabel(r'$\frac{Z-F}{Z}$', rotation = 0, labelpad=30, loc='center')
plt.xlabel(r"$\frac{\sin(\theta/2)}{\lambda} (\AA^{-1})$")
plt.grid(True)
plt.show()

# %% [markdown]
# (Freeman, Acta Cryst., 1959)
#
# *Needed to chop off the top half of the figure because of some weird artifact in the pdf copy that warped the function plot and axes?

# %%
import matplotlib.pyplot as plt
import pandas as pd
#from google.colab import drive
from pathlib import Path

notebook_dir = Path().resolve() 

file_path_Si = notebook_dir / "Datathief" / "Si_trace.txt"
file_path_Si3 = notebook_dir / "Datathief" / "Si_3.txt"
file_path_Si4 = notebook_dir / "Datathief" / "Si_4.txt"
file_path_Si_JB = notebook_dir / "Datathief" / "Si_JB_trace.txt"



data_Si = []
data_Si3 = []
data_Si4 = []
data_Si_JB = []


with open(file_path_Si, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data_Si.append([float(values[0]), float(values[1])])

with open(file_path_Si3, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data_Si3.append([float(values[0]), float(values[1])])

with open(file_path_Si4, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data_Si4.append([float(values[0]), float(values[1])])

with open(file_path_Si_JB, 'r') as file:
    file.readline()
    for line in file:
        if line.strip():
            values = line.strip().split(',')
            data_Si_JB.append([float(values[0]), float(values[1])])

df_Si= pd.DataFrame(data_Si, columns=['X','Y'])
df_Si3= pd.DataFrame(data_Si3, columns=['X','Y'])
df_Si4= pd.DataFrame(data_Si4, columns=['X','Y'])
df_Si_JB = pd.DataFrame(data_Si_JB, columns=['X','Y'])

plt.plot(df_Si['X'], df_Si['Y']/14, marker='x', linestyle='-', color='r', alpha=0.3, markersize=0.4, markeredgewidth=2, label ='Si')
plt.plot(df_Si3['X'], df_Si3['Y']/14, marker='x', linestyle='-', color='g', alpha=0.3, markersize=0.4, markeredgewidth=2, label = 'Si 3+')
plt.plot(df_Si4['X'], df_Si4['Y']/14, marker='x', linestyle='-', color='b', alpha=0.3, markersize=0.4, markeredgewidth=2, label ='Si 3+')
plt.plot(df_Si_JB['X'], df_Si_JB['Y']/14, marker='x', linestyle='-', color='m', alpha=0.3, markersize=0.4, markeredgewidth=2, label = 'Si JB')

plt.title('Si')
plt.ylabel(r'$\frac{Z-F}{Z}$', rotation=0, labelpad=30)
plt.xlabel(r"$\frac{\sin(\theta/2)}{\lambda} (\AA^{-1})$")
plt.grid(True)
plt.show()

# %% [markdown]
# (Freeman, Acta Cryst., 1959)

# %% [markdown]
# ## To Do:
# 1. Convert x axis to angle

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.constants as sc

#print(sc.h)
def x_to_theta(x, wavelength):
    return 2 * np.arcsin(x * wavelength) * (180 / np.pi) 

lambda_val=180e-12 #De Broglie wavelength of a neutron, from wikipedia

df_Si1['Theta']= x_to_theta(df_Si1['x'], lambda_val)
df_Si['Theta'] = x_to_theta(df_Si['X'], lambda_val)
df_Si3['Theta'] = x_to_theta(df_Si3['X'], lambda_val)
df_Si4['Theta'] = x_to_theta(df_Si4['X'], lambda_val)
df_Si_JB['Theta'] = x_to_theta(df_Si_JB['X'], lambda_val)
df_Ge['Theta'] = x_to_theta(df_Ge["X"], lambda_val)
df_Ge_WH['Theta'] = x_to_theta(df_Ge_WH['X'], lambda_val)
df_Ge1['Theta'] = x_to_theta(df_Ge1['x'], lambda_val)

plt.plot(df_Si['Theta'], df_Si['Y']/14, marker=r'$\theta$', linestyle='-', color='r', alpha=0.3, markersize=0.4, markeredgewidth=2, label ='Si')
plt.plot(df_Si3['Theta'], df_Si3['Y']/14, marker=r'$\theta$', linestyle='-', color='g', alpha=0.3, markersize=0.4, markeredgewidth=2, label = 'Si 3+')
plt.plot(df_Si4['Theta'], df_Si4['Y']/14, marker=r'$\theta$', linestyle='-', color='b', alpha=0.3, markersize=0.4, markeredgewidth=2, label ='Si 3+')
plt.plot(df_Si_JB['Theta'], df_Si_JB['Y']/14, marker=r'$\theta$', linestyle='-', color='m', alpha=0.3, markersize=0.4, markeredgewidth=2, label = 'Si JB')

plt.plot(df_Si1['Theta'], df_Si1['S(x,Z)']/14, label = "Si")
plt.plot(df_Ge1['Theta'], df_Ge1['S(X,Z)']/32, label = "Ge")

plt.plot(df_Ge['Theta'], df_Ge['Y']/32, marker='x', linestyle='-', color='r', alpha=0.3, markersize=0.4, markeredgewidth=2, label ='Ge')
plt.plot(df_Ge_WH['Theta'], df_Ge_WH['Y']/32, marker='x', linestyle='-', color='g', alpha=0.3, markersize=0.4, markeredgewidth=2, label = 'Ge Waller Hartree')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\neutroncapture\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.conda\envs\neutroncapture\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\neutroncapture\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'X'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 19>()
#      17 df_Ge['Theta'] = x_to_theta(df_Ge["X"], lambda_val)
#      18 df_Ge_WH['Theta'] = x_to_theta(df_Ge_WH['X'], lambda_val)
# ---> 19 df_Ge1['Theta'] = x_to_theta(df_Ge1['X'], lambda_val)
#      21 plt.plot(df_Si['Theta'], df_Si['Y']/14, marker=r'$\theta$', linestyle='-', color='r', alpha=0.3, markersize=0.4, markeredgewidth=2, label ='Si')
#      22 plt.plot(df_Si3['Theta'], df_Si3['Y']/14, marker=r'$\theta$', linestyle='-', color='g', alpha=0.3, markersize=0.4, markeredgewidth=2, label = 'Si 3+')
#
# File ~\.conda\envs\neutroncapture\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\.conda\envs\neutroncapture\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'X'
